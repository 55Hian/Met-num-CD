# %%
import numpy
import math

h = 0
y = []
t = 0
i = 0
y.append(1)



while t < 10:
    
    i += 1
    y.append(y[i] + (3 + math.exp(-t)-0.5*y[i])) 
    print(y)
    t += 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[41], line 15
#      12 while t < 10:
#      14     i += 1
# ---> 15     y.append(y[i] + (3 + math.exp(-t)-0.5*y[i]))
#      16     print(y)
#      17     t += 1
#
# IndexError: list index out of range

# %%
import numpy
import math
h = 0.01
t = 0
y = 0

print (f"t={t}y={y}")
while t<10:
    y = y + (3 + math.exp(-t)-0.5*y)
    t = t+h
    print (f"t={t}y={y}")
# Out:
# t=0y=0
# t=0.01y=4.0
# t=0.02y=5.990049833749168
# t=0.03y=6.97522359018134
# t=0.04y=7.458057328639178
# t=0.05y=7.689818103471913
# t=0.060000000000000005y=7.7961384762366706
# t=0.07y=7.839833771702584
# t=0.08y=7.85231070575724
# t=0.09y=7.849271699265255
# t=0.09999999999999999y=7.838567034903856
# t=0.10999999999999999y=7.824120935487888
# t=0.11999999999999998y=7.807894603040472
# t=0.12999999999999998y=7.790867738237393
# t=0.13999999999999999y=7.773529300039258
# t=0.15y=7.756122885418435
# t=0.16y=7.738769419134275
# t=0.17y=7.721528498533349
# t=0.18000000000000002y=7.704429065863058
# t=0.19000000000000003y=7.687484744342801
# t=0.20000000000000004y=7.670701506114763
# t=0.21000000000000005y=7.654081506135363
# t=0.22000000000000006y=7.637624999037868
# t=0.23000000000000007y=7.6213312974814125
# t=0.24000000000000007y=7.60519925124404
# t=0.25000000000000006y=7.589227486688573
# t=0.26000000000000006y=7.573414526415691
# t=0.2700000000000001y=7.557758849011412
# ...
